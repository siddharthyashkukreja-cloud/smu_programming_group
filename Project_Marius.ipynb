# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import RidgeCV, LassoCV, ElasticNetCV
from sklearn.model_selection import train_test_split

# %%
#data loading
#   '/Users/siddharth/Downloads/'
#   '/Users/mariusandersen/Library/CloudStorage/OneDrive-BINorwegianBusinessSchool(BIEDU)/Programmming for biz analytics/Project/'

# update before you run:-
FILE_PATH = '/Users/siddharth/Downloads/'
train = pd.read_csv(FILE_PATH + 'train.csv')
test = pd.read_csv(FILE_PATH + 'test.csv')
#print(train.describe())
#print(train.info())
print(f"train: {train.shape}, test: {test.shape}")
train.head(10)
train.dtypes.value_counts()
# Out:
# train: (1460, 81), test: (1459, 80)
# object     43
# int64      35
# float64     3
# Name: count, dtype: int64

# %%
#number of missing values?
missing = train.isnull().sum().sort_values(ascending=False)
missing[missing > 0]
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# MasVnrType       872
# FireplaceQu      690
# LotFrontage      259
# GarageYrBlt       81
# GarageCond        81
# GarageType        81
# GarageFinish      81
# GarageQual        81
# BsmtFinType2      38
# BsmtExposure      38
# BsmtQual          37
# BsmtCond          37
# BsmtFinType1      37
# MasVnrArea         8
# Electrical         1
# dtype: int64

# %%
# correlation with target
corr = train.corr(numeric_only=True)['SalePrice'].sort_values(ascending=False)
corr.head(25)
# Out:
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# GarageYrBlt     0.486362
# MasVnrArea      0.477493
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# LotFrontage     0.351799
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# HalfBath        0.284108
# LotArea         0.263843
# BsmtFullBath    0.227122
# BsmtUnfSF       0.214479
# BedroomAbvGr    0.168213
# ScreenPorch     0.111447
# Name: SalePrice, dtype: float64

# %%
sns.histplot(train['SalePrice'], kde=True)
print(f'Skew: {train['SalePrice'].skew()}')
# Out:
# Skew: 1.8828757597682129

# %%
train['SalePrice_log'] = np.log(train['SalePrice'])
sns.histplot(train['SalePrice_log'], kde=True)
print(f'skew: {train['SalePrice_log'].skew()}')
#llog transformation of sale price: reduces the skew and moves us closer to normal
# Out:
# skew: 0.12133506220520406

# %%
sns.scatterplot(data = train, y = 'SalePrice', x = 'GrLivArea')
plt.title('price vs size')
#scatter plot of house size vs sale price shows two leverage points --> remove? --> cutoff GrLivArea at 4000?
# Out:
# Text(0.5, 1.0, 'price vs size')

# %% [markdown]
# ## Data cleaning and dealing with categorical features

# %%
y_train_raw = train["SalePrice"].reset_index(drop=True)
ntrain = train.shape[0]
all_data = pd.concat([train.drop(columns=["SalePrice"]), test], axis=0, ignore_index=True)

# %% [markdown]
# ### Cleaning categorical features

# %%
#columns where NA means none:
none_cols = ["PoolQC", "MiscFeature", "Alley", "Fence", "FireplaceQu",
             "GarageType", "GarageFinish", "GarageQual", "GarageCond",
             "BsmtQual", "BsmtCond", "BsmtExposure", "BsmtFinType1", "BsmtFinType2",
             "MasVnrType"]
for c in none_cols:
    all_data[c] = all_data[c].fillna("None")

#columns wheere NA means 0
zero_cols = ["GarageYrBlt", "GarageArea", "GarageCars",
             "BsmtFinSF1", "BsmtFinSF2", "BsmtUnfSF", "TotalBsmtSF",
             "BsmtFullBath", "BsmtHalfBath", "MasVnrArea"]
for c in zero_cols:
    all_data[c] = all_data[c].fillna(0)

# Utilities: almost constant --> drop column
all_data = all_data.drop(columns=["Utilities"])

# Numerical columns that should be traeated as categorical
all_data["MSSubClass"] = all_data["MSSubClass"].astype(str)
all_data["MoSold"] = all_data["MoSold"].astype(str)

#LotFrontage --> impute by median based on neighborhood?
all_data["LotFrontage"] = all_data["LotFrontage"].fillna(
    all_data.groupby("Neighborhood")["LotFrontage"].transform("median")
)

#MSZoning --> zoning classification of the sale --> use neighboorhood mode?
all_data['MSZoning'] = all_data['MSZoning'].fillna(all_data['MSZoning'].mode()[0])

#Testing mode imputation for the remainign missing observations
mode_cols = ["Electrical", "KitchenQual", "Exterior1st", "Exterior2nd",
             "SaleType", "Functional"]
for c in mode_cols:
    all_data[c] = all_data[c].fillna(all_data[c].mode()[0])

# %%
remaining_na = all_data.isnull().sum()
remaining_na = remaining_na[remaining_na > 0]
print(remaining_na)
# Out:
# SalePrice_log    1459
# dtype: int64

# %% [markdown]
# ### Dealing with ordinal data --> mapping?

# %% [markdown]
# # Feature engineering

# %% [markdown]
# # Final preprocessing

# %%
# split back into cleaned train and test samples
train_clean_full = all_data.iloc[:ntrain, :].copy()
train_clean_full["SalePrice"] = y_train_raw.values
test_clean = all_data.iloc[ntrain:, :].reset_index(drop=True)

y = np.log(train_clean_full["SalePrice"])
X = train_clean_full.drop(columns=["Id", "SalePrice","SalePrice_log"])
X_test = test_clean.drop(columns=["Id"])

numeric_features = X.select_dtypes(include=[np.number]).columns.tolist()
categorical_features = X.select_dtypes(include=["object"]).columns.tolist()
print(f"{len(numeric_features)} numeric, {len(categorical_features)} categorical features")
# Out:
# 34 numeric, 44 categorical features

# %%
#sklearn preprocessing pipeline

# Standardising numerical feature for Ridge and LASSO
numeric_pipeline = Pipeline([
    ("scale", StandardScaler()),
])

# one-hot-encoding of categorical features
categorical_pipeline = Pipeline([
    ("impute", SimpleImputer(strategy="constant", fill_value="None")),
    ("onehot", OneHotEncoder(handle_unknown="ignore", sparse_output=False)),
])

preprocessor = ColumnTransformer([
    ("num", numeric_pipeline, numeric_features),
    ("cat", categorical_pipeline, categorical_features),
])
